# %% [markdown]
# # Notebook 4
#
# - If you work on Google Colab, [![open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/jouvetg/glamod/blob/main/04_notebook/glacier-modelling-4.ipynb) and you will donwload the repo  below. Make sure to activate the GPU on Colab "Runtime" -> "Change Runtime Type" -> Slect GPU.
#
# - If you work locally on your own PC, you can download the repo
# ```bash
# git clone --depth 1 https://github.com/jouvetg/glamod.git
# ```
# and then go the notebook folder, and work from there.

# %% [markdown]
# ## How to install IGM?
#
# Running IGM consists of running a python script `igm_run`, which is made of functions of the `igm` python package.  First of all, one needs to install igm as follows: (this may take a while, and it may crashes the first time, but should work the second time).

# %%
! pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple igm-model-testing-package==3.0.5
! pip install ml-dtypes==0.5.3
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Requirement already satisfied: igm-model-testing-package==3.0.5 in /usr/local/lib/python3.12/dist-packages (3.0.5)
# Requirement already satisfied: tensorflow==2.17.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.16.3)
# Requirement already satisfied: netCDF4==1.6.0 in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2025.12.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.4.4)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.7.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.1.1)
# Requirement already satisfied: oggm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.6.2)
# Requirement already satisfied: salem in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (0.3.11)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (4.67.1)
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.3.2)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2.3.0)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.26.4)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (1.6.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.76.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.3.4.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.3.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.107)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.7.29 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (8.9.7.29)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.12.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.0.12.1)
# Requirement already satisfied: nvidia-curand-cu12==10.3.4.107 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (10.3.4.107)
# Requirement already satisfied: nvidia-cusolver-cu12==11.5.4.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (11.5.4.101)
# Requirement already satisfied: nvidia-cusparse-cu12==12.2.0.103 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.2.0.103)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.3.101 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (12.3.101)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->igm-model-testing-package==3.0.5) (2025.11.12)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->igm-model-testing-package==3.0.5) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (2.9.0.post0)
# Requirement already satisfied: configobj in /usr/local/lib/python3.12/dist-packages (from oggm->igm-model-testing-package==3.0.5) (5.0.9)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (25.4.0)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (1.1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from salem->igm-model-testing-package==3.0.5) (1.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.2)
# Using cached ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.3
#     Uninstalling ml_dtypes-0.5.3:
#       Successfully uninstalled ml_dtypes-0.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jax 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# tensorstore 0.1.80 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jaxlib 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed ml-dtypes-0.4.1
# Collecting ml-dtypes==0.5.3
#   Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml-dtypes==0.5.3) (1.26.4)
# Using cached ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.3 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed ml-dtypes-0.5.3

# %% [markdown]
# ## Download the data

# %% [markdown]
# Let's now download the repo with the data if you are using Colab

# %%
import sys, os

if "google.colab" in sys.modules:
    print("Running in Colab: cloning repo...")
    # !git clone --depth 1 https://github.com/jouvetg/glamod.git
    # !apt-get install tree -q
else:
    print("Running locally: using local files.")
# Out:
# Running in Colab: cloning repo...
# Cloning into 'glamod'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 81 (delta 10), reused 57 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 14.05 MiB | 44.55 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# tree is already the newest version (2.0.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %% [markdown]
# Let's now go the working folder

# %%
if "google.colab" in sys.modules:
    # %cd /content/glamod/04_notebook
# Out:
# /content/glamod/04_notebook

# %% [markdown]
# # Modelling Glacier du Mont Miné
#
# In this notebook we aim to model the evolution of "[Glacier du Mont Miné](https://www.google.com/maps/place/Mont+Min%C3%A9+Glacier/@46.0145075,7.4877889,24811m/data=!3m1!1e3!4m6!3m5!1s0x478f2db4b5d1a731:0x2c7d28e4d7f7bb26!8m2!3d46.014!4d7.54439!16s%2Fm%2F04n61lb?entry=ttu&g_ep=EgoyMDI0MTAyNy4wIKXMDSoASAFQAw%3D%3D,)" located in te South of Sion (Valais, Switzerland), from the end of the little ice age (about 1850) to now, the goal being to calibrate the glacier model to match the OSL data. To this aim, we take over the material from the previous notebook, and apply it Mont Miné.
#
# You may find on slides 28 to 30 some graphical [illustrations](https://www.unige.ch/forel/application/files/3116/5476/6042/F-Evolene-Paysagesglaciaires_compressed.pdf) of the retreat of the Mont Miné Glacier since the end of the Little Ice Age (LIA).

# %% [markdown]
# Running `igm_run +experiment=params` will  collect the data, run the model forward in time from 1700 to 2024 with a rather simple surface mass balance parametrized by the equilibrium line altitude, and save the output in a netCDF file `output.nc`.

# %%
! igm_run +experiment=params
# Out:
# 2026-01-09 22:49:17.292976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 22:49:17.325429: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 22:49:17.335516: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 22:49:17.358945: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-09 22:49:20.602462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767998964.250369   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.299909   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.300301   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1767998964.300801   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1767998964.301822   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.302082   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.302365   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.495600   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.495987   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767998964.496268   11562 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-09 22:49:24.496435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.smb_simple' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_simple/__init__.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2026-01-09 22:49:26.770440: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1767998966.843424   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.884922   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.886186   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.893449   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.894785   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.896079   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.897229   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.898426   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.899635   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.901077   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.902299   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.905086   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.906299   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.907519   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.910168   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.924967   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.943750   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.981244   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.982465   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.983743   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.985041   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.986265   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.987475   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998966.988691   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.003819   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.005078   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.006347   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.007628   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.008900   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.010189   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.011551   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.012937   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.014452   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.016133   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998967.023711   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1767998975.094498   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.095736   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.097074   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.104449   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.105895   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.107383   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.108813   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.110265   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.112030   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.113696   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.134680   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.138483   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.166141   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.168252   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.170512   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.171823   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.174577   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.178703   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.181323   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.183104   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.184715   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.187582   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.189491   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.193066   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.196981   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.220295   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.221516   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.222779   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.224161   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.225325   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.226490   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.227649   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.229175   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.230632   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.231969   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.239574   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.242980   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.244205   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.245570   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.246851   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.248175   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.249626   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.251112   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.252894   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.255040   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767998975.257882   11562 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=22:49:47, 🔄=000100, ⏱ Time=0001729.9 yr, ⏳ Step=0.18 yr, ❄️  Volume=1.19 km³
# IGM , 🕒=22:49:57, 🔄=000200, ⏱ Time=0001746.3 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.39 km³
# IGM , 🕒=22:50:08, 🔄=000300, ⏱ Time=0001761.0 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.53 km³
# IGM , 🕒=22:50:17, 🔄=000400, ⏱ Time=0001775.3 yr, ⏳ Step=0.14 yr, ❄️  Volume=1.63 km³
# IGM , 🕒=22:50:26, 🔄=000500, ⏱ Time=0001789.2 yr, ⏳ Step=0.14 yr, ❄️  Volume=1.70 km³
# IGM , 🕒=22:50:38, 🔄=000600, ⏱ Time=0001803.5 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.75 km³
# IGM , 🕒=22:50:48, 🔄=000700, ⏱ Time=0001818.0 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.79 km³
# IGM , 🕒=22:50:59, 🔄=000800, ⏱ Time=0001832.5 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.82 km³
# IGM , 🕒=22:51:09, 🔄=000900, ⏱ Time=0001847.0 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.84 km³
# IGM , 🕒=22:51:22, 🔄=001000, ⏱ Time=0001861.6 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.84 km³
# IGM , 🕒=22:51:33, 🔄=001100, ⏱ Time=0001876.8 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.79 km³
# IGM , 🕒=22:51:47, 🔄=001200, ⏱ Time=0001892.4 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.67 km³
# IGM , 🕒=22:51:59, 🔄=001300, ⏱ Time=0001909.0 yr, ⏳ Step=0.17 yr, ❄️  Volume=1.52 km³
# IGM , 🕒=22:52:13, 🔄=001400, ⏱ Time=0001926.7 yr, ⏳ Step=0.18 yr, ❄️  Volume=1.41 km³
# IGM , 🕒=22:52:28, 🔄=001500, ⏱ Time=0001945.4 yr, ⏳ Step=0.19 yr, ❄️  Volume=1.33 km³
# IGM , 🕒=22:52:44, 🔄=001600, ⏱ Time=0001965.1 yr, ⏳ Step=0.21 yr, ❄️  Volume=1.28 km³
# IGM , 🕒=22:53:01, 🔄=001700, ⏱ Time=0001986.1 yr, ⏳ Step=0.22 yr, ❄️  Volume=1.22 km³
# IGM , 🕒=22:53:18, 🔄=001800, ⏱ Time=0002009.2 yr, ⏳ Step=0.24 yr, ❄️  Volume=1.17 km³
# IGM , 🕒=22:53:37, 🔄=001861, ⏱ Time=0002024.0 yr, ⏳ Step=0.21 yr, ❄️  Volume=1.14 km³

# %% [markdown]
# Explore `params.yaml` to see the details of the configuration. A closer look at the parameter file shows that we declare some physical modules, such as `smb_simple`, `iceflow`, `time`, and `thk`.
#
# The first module `smb_simple` computes the surface mass balance as $SMB(z) = \alpha (z - z_{ELA})$, with one SMB gradient $\beta_{abl}$ in the ablation area when $z < z_{ELA}$, and one SMB gradient $\beta_{acc}$ in the accumulation area when $z > z_{ELA}$, along with a maximum SMB capping value of $a_{max}$, as illustrated in the following figure:

# %%
import numpy as np
import matplotlib.pyplot as plt

def surface_mass_balance(z, z_ELA, beta_abl, beta_acc, a_max):
    smb = np.zeros_like(z)
    smb[z < z_ELA] = beta_abl * (z[z < z_ELA] - z_ELA)
    smb[z > z_ELA] = beta_acc * (z[z > z_ELA] - z_ELA)
    smb[smb > a_max] = a_max
    return smb

z = np.linspace(1000, 4000, 100)
smb_values = surface_mass_balance(z, z_ELA= 3000, beta_abl= 0.005, beta_acc= 0.002, a_max= 1.0)

plt.figure(figsize=(10, 6))
plt.plot(z, smb_values, label='Surface Mass Balance (SMB)', color='blue')
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)  # Line at 0
plt.axvline(3000, color='red', linestyle='--', label='ELA (z_ELA)', linewidth=1)  # ELA line
plt.title('Surface Mass Balance as a Function of Elevation')
plt.xlabel('Elevation (m)')
plt.ylabel('Surface Mass Balance (SMB)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# In `params.yaml`, the SMB parameters are evolving with time as follows:
#
# ```yaml
#       - ["time", "gradabl", "gradacc", "ela", "accmax"]
#       - [ 1700,      0.009,     0.005,  2850,      2.0]
#       - [ 1800,      0.009,     0.005,  2900,      2.0]
#       - [ 1850,      0.009,     0.005,  2900,      2.0]
#       - [ 1900,      0.009,     0.005,  3000,      2.0]
#       - [ 2000,      0.009,     0.005,  3100,      2.0]
#       - [ 2024,      0.009,     0.005,  3100,      2.0]
# ```
# this allows us to describe a changing ELA to mimic with an advance (to the little ice age), followed by a retreat as the one observed since the end of the little ice age (LIA).
#
# Let's now look at the results, vizualizing the time evolution of the glacier :

# %%
import importlib
import helper
importlib.reload(helper)
from helper import *
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    # Visualize ice thickness evolution with sample locations
    animate_glacier_evolution(output_files[-1], variable='thk', log_scale=False, show_samples=True)
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    animate_glacier_evolution('output.nc', variable='thk', log_scale=False, show_samples=True)
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 3 output file(s). Using: outputs/2026-01-09/22-49-24/output.nc
# /content/glamod/04_notebook/helper.py:182: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.92, 0.96])

# %% [markdown]
# ## Analyzing the Time Series Results
#
# Let's examine how the glacier evolved under the climate scenario:

# %%
from helper import analyze_time_series
import glob

# Find time series files
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    analyze_time_series(ts_files[-1])
elif os.path.exists('output_ts.nc'):
    analyze_time_series('output_ts.nc')
else:
    print("No output_ts.nc file found.")

# %% [markdown]
# ## Glacier Velocity Evolution
#
# Now let's visualize the ice velocity magnitude evolution in log scale. This shows the flow dynamics and where the glacier is moving fastest.

# %%
from helper import animate_glacier_evolution
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    # Visualize velocity evolution with sample locations
    animate_glacier_evolution(output_files[-1], variable='velbar_mag', log_scale=True, show_samples=True)
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    animate_glacier_evolution('output.nc', variable='velbar_mag', log_scale=True, show_samples=True)
else:
    print("No output.nc files found. Please run the model first.")

# %% [markdown]
# Now, we can visualize the time evolution of the modelled ice thickness at the location of each samples using the following plot.

# %%
from helper import *
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    plot_thk_at_sample(output_files[-1])
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    plot_thk_at_sample('output.nc')
else:
    print("No output.nc files found. Please run the model first.")

# %% [markdown]
# Modify the parameters in `yaml.json` as follows (tips: you may use a copy -- e.g. `params_0.yaml` -- to keep experimenting without losing the original setup):
#
# - Change the SMB parameters: initially adjust the ELA values over time, and later consider modifying the mass balance gradients and maximum accumulation values.
# - Set the parameter "iflo_init_slidingco" to a higher value (e.g., 0.4 for less basal sliding) and a lower value (e.g., 0.1 for more basal sliding).
#
# After making these changes, observe how they affect the glacier, and attempt to align the model (by changing iteratively parameters) with the ages of the collected samples.

# %% [markdown]
# ## To go further : using a **true** Surface Mass Balance Model
#
# As we did in notebook 2, you may replace the simple Surface Mass Balance (SMB) model with an improved model known as the [Positive Degree Day Model (PDD)](https://www.antarcticglaciers.org/glaciers-and-climate/numerical-ice-sheet-models/modelling-glacier-melt/).
